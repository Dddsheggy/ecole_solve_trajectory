# %%
import pickle
import gzip
import numpy as np


sample = 'samples/sample_20368.pkl'

with gzip.open(sample, 'rb') as f:
    d = pickle.load(f)

print(d)

for data in d[2:]:
    print(data)
    print(len(data))
    cnt = 0
    
    for num in data:
        if np.isnan(num):
            cnt += 1
    print(cnt)
# Out:
# [<ecole.core.observation.NodeBipartiteObs object at 0x7f4580318070>, 359, array([ 21,  24,  49,  57,  59,  66,  70,  75,  83,  88,  90,  95, 105,
#        112, 142, 148, 158, 161, 170, 183, 196, 203, 223, 224, 257, 302,
#        305, 329, 335, 359, 373], dtype=uint64), array([1.00000000e-12, 1.00000000e-12,            nan, 5.90470169e-10,
#        5.77988391e-04,            nan,            nan, 5.77988391e-04,
#        1.00000000e-12, 1.00000000e-12, 5.77988391e-04, 5.77988391e-04,
#        5.77988391e-04, 4.97961453e-11, 1.00000000e-12, 1.00000000e-12,
#        5.77988391e-04, 1.00000000e-12, 1.00000000e-12, 1.00000000e-12,
#        1.00000000e-12, 1.00000000e-12, 5.77988391e-04,            nan,
#        1.00000000e-12, 5.77988391e-04, 5.77988391e-04,            nan,
#        5.90470169e-10,            nan,            nan,            nan,
#                   nan,            nan, 2.55174990e-09,            nan,
#        1.00000000e-12, 5.77988391e-04,            nan, 1.00000000e-12,
# ...

# %%
sample = 'samples/sample_47864.pkl'

with gzip.open(sample, 'rb') as f:
    d = pickle.load(f)

print(d)

for data in d[2:]:
    print(data)
    print(len(data))
    cnt = 0
    
    for num in data:
        if np.isnan(num):
            cnt += 1
    print(cnt)
# Out:
# [<ecole.core.observation.NodeBipartiteObs object at 0x7f41a8d9b970>, 213, array([ 48,  69, 150, 182, 191, 210, 213, 226, 230, 279, 328, 345],
#       dtype=uint64), array([5.38636838e-04, 1.00000000e-12, 1.00000000e-12, 1.00000000e-12,
#        5.00945465e-07,            nan,            nan, 5.38636838e-04,
#        6.08224064e-07, 5.10283519e-07,            nan, 1.00000000e-12,
#        1.00000000e-12, 1.00000000e-12, 1.00000000e-12, 1.00000000e-12,
#        4.56416628e-07, 1.00000000e-12, 1.00000000e-12, 5.38636838e-04,
#        1.00000000e-12, 5.03741666e-07, 1.00000000e-12, 1.00000000e-12,
#        2.16367382e-05, 1.00000000e-12, 1.00000000e-12, 1.37789050e-08,
#        1.16367382e-05, 5.38636838e-04, 1.00000000e-12, 5.38636838e-04,
#        1.00000000e-12, 1.00000000e-12, 5.21814548e-07, 1.00000000e-12,
#        5.37289461e-07, 5.38636838e-04, 1.00000000e-12, 1.00000000e-12,
#        5.78425393e-07,            nan, 1.00000000e-12, 5.62850732e-07,
# ...
